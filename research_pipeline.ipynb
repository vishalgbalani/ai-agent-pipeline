# %%
import os
import requests
from dotenv import load_dotenv
from pydantic import BaseModel
from typing import List
from agents import Agent, Runner, function_tool

load_dotenv()
print("Setup complete!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pydantic/_internal/_typing_extra.py:492, in _eval_type_backport(value, globalns, localns, type_params)
#     491 try:
# --> 492     return _eval_type(value, globalns, localns, type_params)
#     493 except TypeError as e:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pydantic/_internal/_typing_extra.py:545, in _eval_type(value, globalns, localns, type_params)
#     544 else:
# --> 545     return typing._eval_type(  # type: ignore
#     546         value, globalns, localns
#     547     )
#
# File ~/opt/anaconda3/lib/python3.9/typing.py:292, in _eval_type(t, globalns, localns, recursive_guard)
#     291 if isinstance(t, ForwardRef):
# --> 292     return t._evaluate(globalns, localns, recursive_guard)
#     293 if isinstance(t, (_GenericAlias, GenericAlias)):
#
# File ~/opt/anaconda3/lib/python3.9/typing.py:554, in ForwardRef._evaluate(self, globalns, localns, recursive_guard)
#     550     globalns = getattr(
#     551         sys.modules.get(self.__forward_module__, None), '__dict__', globalns
#     552     )
#     553 type_ = _type_check(
# --> 554     eval(self.__forward_code__, globalns, localns),
#     555     "Forward references must evaluate to types.",
#     556     is_argument=self.__forward_is_argument__,
#     557     allow_special_forms=self.__forward_is_class__,
#     558 )
#     559 self.__forward_value__ = _eval_type(
#     560     type_, globalns, localns, recursive_guard | {self.__forward_arg__}
#     561 )
#
# File <string>:1, in <module>
#
# TypeError: unsupported operand type(s) for |: 'type' and 'NoneType'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 6>()
#       4 from pydantic import BaseModel
#       5 from typing import List
# ----> 6 from agents import Agent, Runner, function_tool
#       8 load_dotenv()
#       9 print("Setup complete!")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/agents/__init__.py:7, in <module>
#       3 from typing import Literal
#       5 from openai import AsyncOpenAI
# ----> 7 from . import _config
#       8 from .agent import (
#       9     Agent,
#      10     AgentBase,
#    (...)
#      14     ToolsToFinalOutputResult,
#      15 )
#      16 from .agent_output import AgentOutputSchema, AgentOutputSchemaBase
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/agents/_config.py:4, in <module>
#       1 from openai import AsyncOpenAI
#       2 from typing_extensions import Literal
# ----> 4 from .models import _openai_shared
#       5 from .tracing import set_tracing_export_api_key
#       8 def set_default_openai_key(key: str, use_for_tracing: bool) -> None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/agents/models/__init__.py:1, in <module>
# ----> 1 from .default_models import (
#       2     get_default_model,
#       3     get_default_model_settings,
#       4     gpt_5_reasoning_settings_required,
#       5     is_gpt_5_default,
#       6 )
#       8 __all__ = [
#       9     "get_default_model",
#      10     "get_default_model_settings",
#      11     "gpt_5_reasoning_settings_required",
#      12     "is_gpt_5_default",
#      13 ]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/agents/models/default_models.py:7, in <module>
#       3 from typing import Optional
#       5 from openai.types.shared.reasoning import Reasoning
# ----> 7 from agents.model_settings import ModelSettings
#       9 OPENAI_DEFAULT_MODEL_ENV_VARIABLE_NAME = "OPENAI_DEFAULT_MODEL"
#      11 # discourage directly accessing this constant
#      12 # use the get_default_model and get_default_model_settings() functions instead
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/agents/model_settings.py:59, in <module>
#      54 Headers: TypeAlias = Mapping[str, Union[str, Omit]]
#      55 ToolChoice: TypeAlias = Union[Literal["auto", "required", "none"], str, MCPToolChoice, None]
#      58 @dataclass
# ---> 59 class ModelSettings:
#      60     """Settings to use when calling an LLM.
#      61
#      62     This class holds optional model configuration parameters (e.g. temperature,
#    (...)
#      66     for the specific model and provider you are using.
#      67     """
#      69     temperature: float | None = None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pydantic/dataclasses.py:313, in dataclass(_cls, init, repr, eq, order, unsafe_hash, frozen, config, validate_on_init, kw_only, slots)
#     310     _pydantic_dataclasses.complete_dataclass(cls, config_wrapper, raise_errors=False)
#     311     return cls
# --> 313 return create_dataclass if _cls is None else create_dataclass(_cls)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pydantic/dataclasses.py:310, in dataclass.<locals>.create_dataclass(cls)
#     306 cls.__pydantic_complete__ = False  # `complete_dataclass` will set it to `True` if successful.
#     307 # TODO `parent_namespace` is currently None, but we could do the same thing as Pydantic models:
#     308 # fetch the parent ns using `parent_frame_namespace` (if the dataclass was defined in a function),
#     309 # and possibly cache it (see the `__pydantic_parent_namespace__` logic for models).
# --> 310 _pydantic_dataclasses.complete_dataclass(cls, config_wrapper, raise_errors=False)
#     311 return cls
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pydantic/_internal/_dataclasses.py:128, in complete_dataclass(cls, config_wrapper, raise_errors, ns_resolver, _force_build)
#     125 cls.__init__ = __init__  # type: ignore
#     126 cls.__pydantic_config__ = config_wrapper.config_dict  # type: ignore
# --> 128 set_dataclass_fields(cls, config_wrapper=config_wrapper, ns_resolver=ns_resolver)
#     130 if not _force_build and config_wrapper.defer_build:
#     131     set_dataclass_mocks(cls)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pydantic/_internal/_dataclasses.py:78, in set_dataclass_fields(cls, config_wrapper, ns_resolver)
#      70 """Collect and set `cls.__pydantic_fields__`.
#      71
#      72 Args:
#    (...)
#      75     ns_resolver: Namespace resolver to use when getting dataclass annotations.
#      76 """
#      77 typevars_map = get_standard_typevars_map(cls)
# ---> 78 fields = collect_dataclass_fields(
#      79     cls, ns_resolver=ns_resolver, typevars_map=typevars_map, config_wrapper=config_wrapper
#      80 )
#      82 cls.__pydantic_fields__ = fields
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pydantic/_internal/_fields.py:502, in collect_dataclass_fields(cls, config_wrapper, ns_resolver, typevars_map)
#     499     continue
#     501 globalns, localns = ns_resolver.types_namespace
# --> 502 ann_type, evaluated = _typing_extra.try_eval_type(dataclass_field.type, globalns, localns)
#     504 if _typing_extra.is_classvar_annotation(ann_type):
#     505     continue
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pydantic/_internal/_typing_extra.py:404, in try_eval_type(value, globalns, localns)
#     401 value = _type_convert(value)
#     403 try:
# --> 404     return eval_type_backport(value, globalns, localns), True
#     405 except NameError:
#     406     return value, False
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pydantic/_internal/_typing_extra.py:455, in eval_type_backport(value, globalns, localns, type_params)
#     445 """An enhanced version of `typing._eval_type` which will fall back to using the `eval_type_backport`
#     446 package if it's installed to let older Python versions use newer typing constructs.
#     447
#    (...)
#     452 This function will also display a helpful error if the value passed fails to evaluate.
#     453 """
#     454 try:
# --> 455     return _eval_type_backport(value, globalns, localns, type_params)
#     456 except TypeError as e:
#     457     if 'Unable to evaluate type annotation' in str(e):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pydantic/_internal/_typing_extra.py:500, in _eval_type_backport(value, globalns, localns, type_params)
#     498     from eval_type_backport import eval_type_backport
#     499 except ImportError:
# --> 500     raise TypeError(
#     501         f'Unable to evaluate type annotation {value.__forward_arg__!r}. If you are making use '
#     502         'of the new typing syntax (unions using `|` since Python 3.10 or builtins subscripting '
#     503         'since Python 3.9), you should either replace the use of new syntax with the existing '
#     504         '`typing` constructs or install the `eval_type_backport` package.'
#     505     ) from e
#     507 return eval_type_backport(
#     508     value,
#     509     globalns,
#     510     localns,  # pyright: ignore[reportArgumentType], waiting on a new `eval_type_backport` release.
#     511     try_default=False,
#     512 )
#
# TypeError: Unable to evaluate type annotation 'float | None'. If you are making use of the new typing syntax (unions using `|` since Python 3.10 or builtins subscripting since Python 3.9), you should either replace the use of new syntax with the existing `typing` constructs or install the `eval_type_backport` package.
